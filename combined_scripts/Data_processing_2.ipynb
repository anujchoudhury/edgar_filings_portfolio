# %%
import re

def extract_header_info(file_path):
    header_info = {}
    patterns = {
        'cik': r'CENTRAL INDEX KEY:\s+(\d+)',
        'conformed_period_report': r'CONFORMED PERIOD OF REPORT:\s+(\d+)',
        'filing_date': r'FILED AS OF DATE:\s+(\d+)',
        'company_name': r'COMPANY CONFORMED NAME:\s+([^\n\r]+)',
        'sic': r'STANDARD INDUSTRIAL CLASSIFICATION:\s+([^\n\r]+)',
        'form_type': r'FORM TYPE:\s+([^\n\r]+)'

    }

    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        
        for key, pattern in patterns.items():
            match = re.search(pattern, content)
            if match:
                header_info[key] = match.group(1).strip()
            else:
                header_info[key] = 'Not found'
    header_info['file_path'] = file_path
    return header_info

# %%
root_path = '/data/workspace_files/10X_cleaned'
dict_arr = []
for yr in [2016, 2017]:
    for qtr in ['QTR1', 'QTR2', 'QTR3', 'QTR4']:
        path = f'{root_path}/{str(yr)}/{qtr}'
        files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
        for fl in files:
            header = extract_header_info(f'{path}/{fl}')
            dict_arr.append(header)
        print(f'Done for {str(yr)} - {qtr}')
# Out:
# Done for 2016 - QTR1
# Done for 2016 - QTR2
# Done for 2016 - QTR3
# Done for 2016 - QTR4
# Done for 2017 - QTR1
# Done for 2017 - QTR2
# Done for 2017 - QTR3
# Done for 2017 - QTR4

# %%
# !pip install pyarrow
import pyarrow.parquet as pq
import pandas as pd
#df = pd.DataFrame(dict_arr)

#df.to_parquet('/data/workspace_files/10X_cleaned/Master_dictionary.parquet')
# Out:
# Collecting pyarrow
#   Downloading pyarrow-15.0.0-cp38-cp38-manylinux_2_28_x86_64.whl (38.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.16.6 in /opt/python/envs/default/lib/python3.8/site-packages (from pyarrow) (1.24.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-15.0.0
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
df = pq.read_table('/data/workspace_files/10X_cleaned/Master_dictionary.parquet').to_pandas()
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cik</th>
#       <th>conformed_period_report</th>
#       <th>filing_date</th>
#       <th>company_name</th>
#       <th>sic</th>
#       <th>form_type</th>
#       <th>file_path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0001553817</td>
#       <td>20160324</td>
#       <td>20160325</td>
#       <td>WFRBS COMMERCIAL MORTGAGE TRUST 2012-C8</td>
#       <td>ASSET-BACKED SECURITIES [6189]</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2016/QTR1/20...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0000008177</td>
#       <td>20151231</td>
#       <td>20160329</td>
#       <td>ATLANTIC AMERICAN CORP</td>
#       <td>LIFE INSURANCE [6311]</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2016/QTR1/20...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0001574085</td>
#       <td>20151231</td>
#       <td>20160315</td>
#       <td>Ashford Hospitality Prime, Inc.</td>
#       <td>REAL ESTATE INVESTMENT TRUSTS [6798]</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2016/QTR1/20...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0001305253</td>
#       <td>20151231</td>
#       <td>20160330</td>
#       <td>Eiger BioPharmaceuticals, Inc.</td>
#       <td>BIOLOGICAL PRODUCTS (NO DIAGNOSTIC SUBSTANCES)...</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2016/QTR1/20...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0001318268</td>
#       <td>20151231</td>
#       <td>20160330</td>
#       <td>Madison Technologies Inc.</td>
#       <td>MINING, QUARRYING OF NONMETALLIC MINERALS (NO ...</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2016/QTR1/20...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>59036</th>
#       <td>0001103601</td>
#       <td>20170930</td>
#       <td>20171122</td>
#       <td>WGL HOLDINGS INC</td>
#       <td>NATURAL GAS DISTRIBUTION [4924]</td>
#       <td>10-K</td>
#       <td>/data/workspace_files/10X_cleaned/2017/QTR4/20...</td>
#     </tr>
#     <tr>
#       <th>59037</th>
#       <td>0000733269</td>
#       <td>20170930</td>
#       <td>20171103</td>
#       <td>ACXIOM CORP</td>
#       <td>SERVICES-COMPUTER PROCESSING &amp; DATA PREPARATIO...</td>
#       <td>10-Q</td>
#       <td>/data/workspace_files/10X_cleaned/2017/QTR4/20...</td>
#     </tr>
#     <tr>
#       <th>59038</th>
#       <td>0001014739</td>
#       <td>20170930</td>
#       <td>20171102</td>
#       <td>BioScrip, Inc.</td>
#       <td>SERVICES-HOME HEALTH CARE SERVICES [8082]</td>
#       <td>10-Q</td>
#       <td>/data/workspace_files/10X_cleaned/2017/QTR4/20...</td>
#     </tr>
#     <tr>
#       <th>59039</th>
#       <td>0001394319</td>
#       <td>20170930</td>
#       <td>20171107</td>
#       <td>Tracon Pharmaceuticals, Inc.</td>
#       <td>BIOLOGICAL PRODUCTS (NO DIAGNOSTIC SUBSTANCES)...</td>
#       <td>10-Q</td>
#       <td>/data/workspace_files/10X_cleaned/2017/QTR4/20...</td>
#     </tr>
#     <tr>
#       <th>59040</th>
#       <td>0001496818</td>
#       <td>20170930</td>
#       <td>20171120</td>
#       <td>STEALTH TECHNOLOGIES, INC.</td>
#       <td>SERVICES-BUSINESS SERVICES, NEC [7389]</td>
#       <td>10-Q</td>
#       <td>/data/workspace_files/10X_cleaned/2017/QTR4/20...</td>
#     </tr>
#   </tbody>
# </table>
# <p>59041 rows × 7 columns</p>
# </div>

# %%
# !pip install nltk

import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk

# Download nltk resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')


def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\W', ' ', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [PorterStemmer().stem(token) for token in tokens if token.isalnum() and token not in stop_words]
    return tokens
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /opt/python/envs/default/lib/python3.8/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/python/envs/default/lib/python3.8/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/python/envs/default/lib/python3.8/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/python/envs/default/lib/python3.8/site-packages (from nltk) (4.66.1)
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# [nltk_data] Downloading package punkt to /home/datalore/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/datalore/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Read the text files
with open('/data/workspace_files/10X_cleaned/2016/QTR2/20160512_10-Q_edgar_data_8177_0001140361-16-064724.txt', 'r', encoding='utf-8') as file:
    text1 = file.read()

with open('/data/workspace_files/10X_cleaned/2017/QTR2/20170512_10-Q_edgar_data_8177_0001140361-17-019978.txt', 'r', encoding='utf-8') as file:
    text2 = file.read()

# Preprocess text (optional, depending

# Tokenize the text into words
tokens1 = preprocess_text(text1)
tokens2 = preprocess_text(text2)

# %%
# Calculate edit distance
edit_distance = nltk.edit_distance(tokens1, tokens2)

print(f"Edit Distance: {edit_distance}")
# Out:
# Edit Distance: 4570

# %%
len(tokens1)
# Out:
# 9238

# %%
tokens1
# Out:
# ['header',
#  'filestat',
#  'filenam',
#  '16',
#  '064724',
#  'txt',
#  'filenam',
#  'grossfiles',
#  '5153583',
#  'grossfiles',
#  'netfiles',
#  '83918',
#  'netfiles',
#  '236144',
#  '2466500',
#  '1523410',
#  '667056',
#  '9',
#  'filestat',
#  'sec',
#  'header',
#  '0001140361',
#  '16',
#  '064724',
#  'hdr',
#  'sgml',
#  '20160512',
#  'accept',
#  'datetim',
#  '20160512113818',
#  'access',
#  'number',
#  '0001140361',
#  '16',
#  '064724',
#  'conform',
#  'submiss',
#  'type',
#  '10',
#  'q',
#  'public',
#  'document',
#  'count',
#  '51',
#  'conform',
#  'period',
#  'report',
#  '20160331',
#  'file',
#  'date',
#  '20160512',
#  'date',
#  'chang',
#  '20160512',
#  'filer',
#  'compani',
#  'data',
#  'compani',
#  'conform',
#  'name',
#  'atlant',
#  'american',
#  'corp',
#  'central',
#  'index',
#  'key',
#  '0000008177',
#  'standard',
#  'industri',
#  'classif',
#  'life',
#  'insur',
#  '6311',
#  'ir',
#  'number',
#  '581027114',
#  'state',
#  'incorpor',
#  'ga',
#  'fiscal',
#  'year',
#  'end',
#  '1231',
#  'file',
#  'valu',
#  'form',
#  'type',
#  '10',
#  'q',
#  'sec',
#  'act',
#  '1934',
#  'act',
#  'sec',
#  'file',
#  'number',
#  '000',
#  '03722',
#  'film',
#  'number',
#  '161642415',
#  'busi',
#  'address',
#  'street',
#  '1',
#  '4370',
#  'peachtre',
#  'rd',
#  'ne',
#  'citi',
#  'atlanta',
#  'state',
#  'ga',
#  'zip',
#  '30319',
#  'busi',
#  'phone',
#  '4042665500',
#  'mail',
#  'address',
#  'street',
#  '1',
#  '4370',
#  'peachtre',
#  'road',
#  'citi',
#  'atlanta',
#  'state',
#  'ga',
#  'zip',
#  '30319',
#  'sec',
#  'header',
#  'header',
#  '0001140361',
#  '16',
#  '064724',
#  'txt',
#  '20160512',
#  '10',
#  'q',
#  '1',
#  'form10q',
#  'htm',
#  'atlant',
#  'american',
#  'corpor',
#  '10',
#  'q',
#  '3',
#  '31',
#  '2016',
#  'unit',
#  'state',
#  'secur',
#  'exchang',
#  'commiss',
#  'washington',
#  'c',
#  '20549',
#  'form',
#  '10',
#  'q',
#  'quarterli',
#  'report',
#  'pursuant',
#  'section',
#  '13',
#  '15',
#  'secur',
#  'exchang',
#  'act',
#  '1934',
#  'quarterli',
#  'period',
#  'end',
#  'march',
#  '31',
#  '2016',
#  'transit',
#  'report',
#  'pursuant',
#  'section',
#  '13',
#  '15',
#  'secur',
#  'exchang',
#  'act',
#  '1934',
#  'commiss',
#  'file',
#  'number',
#  '0',
#  '3722',
#  'atlant',
#  'american',
#  'corpor',
#  'exact',
#  'name',
#  'registr',
#  'specifi',
#  'charter',
#  'georgia',
#  '58',
#  '1027114',
#  'state',
#  'jurisdict',
#  'incorpor',
#  'organ',
#  'r',
#  'employ',
#  'identif',
#  '4370',
#  'peachtre',
#  'road',
#  'n',
#  'e',
#  '30319',
#  'atlanta',
#  'georgia',
#  'zip',
#  'code',
#  'address',
#  'princip',
#  'execut',
#  'offic',
#  '404',
#  '266',
#  '5500',
#  'registr',
#  'telephon',
#  'number',
#  'includ',
#  'area',
#  'code',
#  'indic',
#  'check',
#  'mark',
#  'whether',
#  'registr',
#  '1',
#  'file',
#  'report',
#  'requir',
#  'file',
#  'section',
#  '13',
#  '15',
#  'secur',
#  'exchang',
#  'act',
#  '1934',
#  'preced',
#  '12',
#  'month',
#  'shorter',
#  'period',
#  'registr',
#  'requir',
#  'file',
#  'report',
#  '2',
#  'subject',
#  'file',
#  'requir',
#  'past',
#  '90',
#  'day',
#  'ye',
#  'indic',
#  'check',
#  'mark',
#  'whether',
#  'registr',
#  'submit',
#  'electron',
#  'post',
#  'corpor',
#  'web',
#  'site',
#  'everi',
#  'interact',
#  'data',
#  'file',
#  'requir',
#  'submit',
#  'post',
#  'pursuant',
#  'rule',
#  '405',
#  'regul',
#  'preced',
#  '12',
#  'month',
#  'shorter',
#  'period',
#  'registr',
#  'requir',
#  'submit',
#  'post',
#  'file',
#  'ye',
#  'indic',
#  'check',
#  'mark',
#  'whether',
#  'registr',
#  'larg',
#  'acceler',
#  'filer',
#  'acceler',
#  'filer',
#  'non',
#  'acceler',
#  'filer',
#  'smaller',
#  'report',
#  'compani',
#  'see',
#  'definit',
#  'larg',
#  'acceler',
#  'filer',
#  'acceler',
#  'filer',
#  'smaller',
#  'report',
#  'compani',
#  'rule',
#  '12b',
#  '2',
#  'exchang',
#  'act',
#  'check',
#  'one',
#  'larg',
#  'acceler',
#  'filer',
#  'acceler',
#  'filer',
#  'non',
#  'acceler',
#  'filer',
#  'check',
#  'smaller',
#  'report',
#  'compani',
#  'smaller',
#  'report',
#  'compani',
#  'indic',
#  'check',
#  'mark',
#  'whether',
#  'registr',
#  'shell',
#  'compani',
#  'defin',
#  'rule',
#  '12b',
#  '2',
#  'exchang',
#  'act',
#  'ye',
#  'total',
#  'number',
#  'share',
#  'registr',
#  'common',
#  'stock',
#  '1',
#  'par',
#  'valu',
#  'outstand',
#  'may',
#  '9',
#  '2016',
#  '20',
#  '419',
#  '486',
#  'atlant',
#  'american',
#  'corpor',
#  'tabl',
#  'content',
#  'part',
#  'financi',
#  'inform',
#  'page',
#  'item',
#  '1',
#  'financi',
#  'statement',
#  'condens',
#  'consolid',
#  'balanc',
#  'sheet',
#  'march',
#  '31',
#  '2016',
#  'decemb',
#  '31',
#  '2015',
#  '2',
#  'condens',
#  'consolid',
#  'statement',
#  'oper',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  '3',
#  'condens',
#  'consolid',
#  'statement',
#  'comprehens',
#  'incom',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  '4',
#  'condens',
#  'consolid',
#  'statement',
#  'sharehold',
#  'equiti',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  '5',
#  'condens',
#  'consolid',
#  'statement',
#  'cash',
#  'flow',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  '6',
#  'note',
#  'condens',
#  'consolid',
#  'financi',
#  'statement',
#  '7',
#  'item',
#  '2',
#  'manag',
#  'discuss',
#  'analysi',
#  'financi',
#  'condit',
#  'result',
#  'oper',
#  '18',
#  'item',
#  '4',
#  'control',
#  'procedur',
#  '24',
#  'part',
#  'ii',
#  'inform',
#  'item',
#  '2',
#  'unregist',
#  'sale',
#  'equiti',
#  'secur',
#  'use',
#  'proce',
#  '25',
#  'item',
#  '6',
#  'exhibit',
#  '25',
#  'signatur',
#  '26',
#  'tabl',
#  'content',
#  'part',
#  'financi',
#  'inform',
#  'item',
#  '1',
#  'financi',
#  'statement',
#  'atlant',
#  'american',
#  'corpor',
#  'condens',
#  'consolid',
#  'balanc',
#  'sheet',
#  'dollar',
#  'thousand',
#  'except',
#  'per',
#  'share',
#  'data',
#  'asset',
#  'unaudit',
#  'march',
#  '31',
#  '2016',
#  'decemb',
#  '31',
#  '2015',
#  'cash',
#  'cash',
#  'equival',
#  '10',
#  '784',
#  '15',
#  '622',
#  'invest',
#  'fix',
#  'matur',
#  'cost',
#  '206',
#  '819',
#  '210',
#  '450',
#  '206',
#  '461',
#  '205',
#  '324',
#  'common',
#  'non',
#  'redeem',
#  'prefer',
#  'stock',
#  'cost',
#  '11',
#  '453',
#  '10',
#  '953',
#  '20',
#  '367',
#  '23',
#  '131',
#  'invest',
#  'asset',
#  'cost',
#  '5',
#  '719',
#  '6',
#  '454',
#  '5',
#  '719',
#  '6',
#  '454',
#  'polici',
#  'loan',
#  '2',
#  '204',
#  '2',
#  '200',
#  'real',
#  'estat',
#  '38',
#  '38',
#  'invest',
#  'unconsolid',
#  'trust',
#  '1',
#  '238',
#  '1',
#  '238',
#  'total',
#  'invest',
#  '236',
#  '027',
#  '238',
#  '385',
#  'receiv',
#  'reinsur',
#  '9',
#  '035',
#  '11',
#  '759',
#  'insur',
#  'premium',
#  'net',
#  'allow',
#  'doubt',
#  'account',
#  '521',
#  '528',
#  '8',
#  '416',
#  '11',
#  '988',
#  'defer',
#  'incom',
#  'tax',
#  'net',
#  '829',
#  'defer',
#  'acquisit',
#  'cost',
#  '27',
#  '669',
#  '27',
#  '866',
#  'asset',
#  '5',
#  '658',
#  '5',
#  '610',
#  'intang',
#  '2',
#  '544',
#  '2',
#  '544',
#  'total',
#  'asset',
#  '300',
#  '133',
#  '314',
#  '603',
#  'liabil',
#  'sharehold',
#  'equiti',
#  'insur',
#  'reserv',
#  'policyhold',
#  'fund',
#  'futur',
#  'polici',
#  'benefit',
#  '72',
#  '468',
#  '72',
#  '136',
#  'unearn',
#  'premium',
#  '17',
#  '533',
#  '25',
#  '348',
#  'loss',
#  'claim',
#  '57',
#  '673',
#  '63',
#  '870',
#  'polici',
#  'liabil',
#  '1',
#  '464',
#  '1',
#  '991',
#  'total',
#  'insur',
#  'reserv',
#  'policyhold',
#  'fund',
#  '149',
#  '138',
#  '163',
#  '345',
#  'account',
#  'payabl',
#  'accru',
#  'expens',
#  '13',
#  '258',
#  '15',
#  '028',
#  'defer',
#  'incom',
#  'tax',
#  'net',
#  '175',
#  'junior',
#  'subordin',
#  'debentur',
#  'oblig',
#  'net',
#  '33',
#  '738',
#  '33',
#  '738',
#  'total',
#  'liabil',
#  '196',
#  '309',
#  '212',
#  '111',
#  'commit',
#  'conting',
#  'note',
#  '7',
#  'sharehold',
#  'equiti',
#  'prefer',
#  'stock',
#  '1',
#  'par',
#  '4',
#  '000',
#  '000',
#  'share',
#  'author',
#  'seri',
#  'prefer',
#  '55',
#  '000',
#  'share',
#  'issu',
#  'outstand',
#  '5',
#  '500',
#  'redempt',
#  'valu',
#  '55',
#  '55',
#  'common',
#  'stock',
#  '1',
#  'par',
#  '50',
#  '000',
#  '000',
#  'share',
#  'author',
#  'share',
#  'issu',
#  '22',
#  '400',
#  '894',
#  'share',
#  'outstand',
#  '20',
#  '391',
#  '363',
#  '20',
#  '426',
#  '536',
#  '22',
#  '401',
#  '22',
#  '401',
#  'addit',
#  'paid',
#  'capit',
#  '56',
#  '633',
#  '56',
#  '623',
#  'retain',
#  'earn',
#  '25',
#  '834',
#  '25',
#  '443',
#  'accumul',
#  'comprehens',
#  'incom',
#  '5',
#  '561',
#  '4',
#  '584',
#  'unearn',
#  'stock',
#  'grant',
#  'compens',
#  '154',
#  '273',
#  'treasuri',
#  'stock',
#  'cost',
#  '2',
#  '009',
#  '531',
#  '1',
#  '974',
#  '358',
#  'share',
#  '6',
#  '506',
#  '6',
#  '341',
#  'total',
#  'sharehold',
#  'equiti',
#  '103',
#  '824',
#  '102',
#  '492',
#  'total',
#  'liabil',
#  'sharehold',
#  'equiti',
#  '300',
#  '133',
#  '314',
#  '603',
#  'accompani',
#  'note',
#  'integr',
#  'part',
#  'consolid',
#  'financi',
#  'statement',
#  '2',
#  'tabl',
#  'content',
#  'atlant',
#  'american',
#  'corpor',
#  'condens',
#  'consolid',
#  'statement',
#  'oper',
#  'unaudit',
#  'dollar',
#  'thousand',
#  'except',
#  'per',
#  'share',
#  'data',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  'revenu',
#  'insur',
#  'premium',
#  '38',
#  '458',
#  '37',
#  '386',
#  'invest',
#  'incom',
#  '2',
#  '507',
#  '2',
#  '597',
#  'realiz',
#  'invest',
#  'gain',
#  'net',
#  '752',
#  '951',
#  'incom',
#  '30',
#  '15',
#  'total',
#  'revenu',
#  '41',
#  '747',
#  '40',
#  '949',
#  'benefit',
#  'expens',
#  'insur',
#  'benefit',
#  'loss',
#  'incur',
#  '24',
#  '825',
#  '25',
#  '241',
#  'commiss',
#  'underwrit',
#  'expens',
#  '11',
#  '827',
#  '10',
#  '721',
#  'interest',
#  'expens',
#  '373',
#  '349',
#  'expens',
#  '3',
#  '346',
#  '3',
#  '628',
#  'total',
#  'benefit',
#  'expens',
#  '40',
#  '371',
#  '39',
#  '939',
#  'incom',
#  'incom',
#  'tax',
#  '1',
#  '376',
#  '1',
#  '010',
#  'incom',
#  'tax',
#  'expens',
#  '478',
#  '319',
#  'net',
#  'incom',
#  '898',
#  '691',
#  'prefer',
#  'stock',
#  'dividend',
#  '99',
#  '99',
#  'net',
#  'incom',
#  'applic',
#  'common',
#  'sharehold',
#  '799',
#  '592',
#  'earn',
#  'per',
#  'common',
#  'share',
#  'basic',
#  'dilut',
#  '04',
#  '03',
#  'accompani',
#  'note',
#  'integr',
#  'part',
#  'consolid',
#  'financi',
#  'statement',
#  '3',
#  'tabl',
#  'content',
#  'atlant',
#  'american',
#  'corpor',
#  'condens',
#  'consolid',
#  'statement',
#  'comprehens',
#  'incom',
#  'unaudit',
#  'dollar',
#  'thousand',
#  'three',
#  'month',
#  'end',
#  'march',
#  '31',
#  '2016',
#  '2015',
#  'net',
#  'incom',
#  '898',
#  '691',
#  'comprehens',
#  'incom',
#  'avail',
#  'sale',
#  'secur',
#  'gross',
#  'unreal',
#  'hold',
#  'gain',
#  'aris',
#  'period',
#  '2',
#  '256',
#  '5',
#  '721',
#  'relat',
#  'incom',
#  'tax',
#  'effect',
#  '790',
#  '2',
#  '003',
#  'less',
#  'reclassif',
#  'adjust',
#  ...]

# %%
import difflib


# Preprocess text (optional, depending on your needs)
text1 = 'we expect prices to rise'
text2 = 'prices are expected to rise'

# Tokenize the text into lines
lines1 = text1.splitlines()
lines2 = text2.splitlines()

# Compute the differences between the two texts
differ = difflib.Differ()
diff = list(differ.compare(lines1, lines2))

# Count the number of added and deleted words
added_words = sum(line.split()[1:] for line in diff if line.startswith('+'))
deleted_words = sum(line.split()[1:] for line in diff if line.startswith('-'))

# Calculate the total count of changes, additions, and deletions
total_changes = len(added_words) + len(deleted_words)

# Calculate the average size of the old and new documents
average_size = (len(lines1) + len(lines2)) / 2

# Normalize the total count by the average size
similarity_measure = total_changes / average_size

print(f"Similarity Measure: {similarity_measure}")
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
diff
# Out:
# ['- we expect prices to rise', '+ prices are expected to rise']
