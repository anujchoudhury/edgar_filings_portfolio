# %%
# !pip install pyarrow
# !pip install wrds
# Out:
# Requirement already satisfied: pyarrow in /opt/python/envs/default/lib/python3.8/site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in /opt/python/envs/default/lib/python3.8/site-packages (from pyarrow) (1.24.3)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: wrds in /opt/python/envs/default/lib/python3.8/site-packages (3.1.6)
# Requirement already satisfied: numpy in /opt/python/envs/default/lib/python3.8/site-packages (from wrds) (1.24.3)
# Requirement already satisfied: pandas in /opt/python/envs/default/lib/python3.8/site-packages (from wrds) (1.5.3)
# Requirement already satisfied: psycopg2-binary in /opt/python/envs/default/lib/python3.8/site-packages (from wrds) (2.9.6)
# Requirement already satisfied: scipy in /opt/python/envs/default/lib/python3.8/site-packages (from wrds) (1.9.1)
# Requirement already satisfied: sqlalchemy<2 in /opt/python/envs/default/lib/python3.8/site-packages (from wrds) (1.4.51)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/python/envs/default/lib/python3.8/site-packages (from sqlalchemy<2->wrds) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/python/envs/default/lib/python3.8/site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/envs/default/lib/python3.8/site-packages (from pandas->wrds) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/python/envs/default/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
import datetime as dt
import os
import pickle
from numpy import dot
from numpy.linalg import norm
import pandas as pd
import numpy as np
import pandas as pd
import os
import sys
import pyarrow.parquet as pq
import re
import yfinance as yf
from datetime import datetime
from dateutil.relativedelta import relativedelta
import wrds
import pytz
import math
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize
from tqdm import tqdm

# %%
def get_sd_and_ed_for_returns(date, lead):
    start_current_month = date.replace(day=1)
    start_current_month = start_current_month + relativedelta(months = lead)
    start_next_month = start_current_month + relativedelta(months=1)
    #start_current_month = start_current_month + relativedelta(months=-2)

    start_current_month_str = start_current_month.strftime("%Y-%m-%d")
    start_next_month_str = start_next_month.strftime("%Y-%m-%d")

    return start_current_month_str, start_next_month_str

# %%
### log-in using your credentials
if 'conn' in locals():
    print("WRDS connection already open!")
else:
    conn = wrds.Connection()
# Out:
# Enter your WRDS username [datalore]: anujchoudhury
# Enter your password: ············
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?:  y
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
def get_req_tick_cik_map(start_date, end_date):
    # Assuming you have already imported the necessary libraries and connected to your database
    # Assuming you have already imported the necessary libraries and connected to your database

    print(start_date)
    print(end_date)

    sql_query = f"""
    SELECT distinct cik, tic, cusip, cshtrm, trt1m, cmth
    FROM comp_na_daily_all.secm
    WHERE datadate >= '{start_date}' and datadate < '{end_date}'
    """

    cik_tick_map = conn.raw_sql(sql_query)
    cik_tick_map = cik_tick_map.dropna(subset=['cik', 'trt1m'])
    cik_tick_map['cik'] = cik_tick_map['cik'].astype(int)

    print("Total rows:", len(cik_tick_map))
    print("Unique cusip count:", cik_tick_map['cusip'].nunique())

    # Identify 'cik' values with multiple rows
    cik_counts = cik_tick_map['cik'].value_counts()
    multiple_cik_values = cik_counts[cik_counts > 1].index.tolist()

    # Create a mask to filter rows for 'cik' values with multiple rows
    multiple_cik_mask = cik_tick_map['cik'].isin(multiple_cik_values)

    # Create a mask to identify rows with null 'cshtrm'
    null_cshtrm_mask = cik_tick_map['cshtrm'].isnull()

    # Apply both masks to filter rows for 'cik' values with multiple rows
    filtered_cik_tick_map = cik_tick_map[multiple_cik_mask & ~null_cshtrm_mask]

    # Group by 'cik' and apply idxmax() to find the index with the largest 'cshtrm'
    grouped_map = filtered_cik_tick_map.groupby(['cik'])['cshtrm'].idxmax()

    # Use loc to select the rows with the largest 'cshtrm' for 'cik' values with multiple rows
    cik_tick_map_with_max_cshtrm = filtered_cik_tick_map.loc[grouped_map]


    # Select rows for 'cik' values that have only one row
    single_row_cik_values = cik_counts[cik_counts == 1].index.tolist()
    single_row_cik_mask = cik_tick_map['cik'].isin(single_row_cik_values)
    cik_tick_map_single_rows = cik_tick_map[single_row_cik_mask]

    # Append rows for 'cik' values with one row to the previously selected rows
    final_cik_tick_map = pd.concat([cik_tick_map_with_max_cshtrm, cik_tick_map_single_rows], axis = 0)
    # Rename the 'trt1m' column to 'ret'
    final_cik_tick_map.rename(columns={'trt1m': 'ret'}, inplace=True)

    print("Total rows after selecting rows with max cshtrm:", len(final_cik_tick_map))


    return final_cik_tick_map

# %%
def get_n_mnths_return(date_obj, lead):
    sd,ed = get_sd_and_ed_for_returns(date_obj, lead)
    cik_tick_map = get_req_tick_cik_map(start_date=sd, end_date=ed)
    
    return cik_tick_map

# %%
date_obj = datetime.strptime('Dec1996', '%b%Y')
data = get_n_mnths_return(date_obj, 2)
# Out:
# 1997-02-01
# 1997-03-01
# Total rows: 11093
# Unique cusip count: 10873
# Total rows after selecting rows with max cshtrm: 10670

# %%
month_dict = { 1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
folder_path = r'/data/workspace_files/parquet_files'

# %%
def create_directories():
    folder_path = '/data/workspace_files/parquet_files'
    n_bucket = 5
    for lead in range(1,13):
        for sim_type in ['cosine_similarity', 'jaccard_similarity']:
            for quartile in range(1,n_bucket + 1):
                folder_path_req = f'{folder_path}/portfolio_lead_lag/{sim_type}/{lead}/Q{quartile}'
                print(folder_path_req)
                os.makedirs(folder_path_req, exist_ok = True)
            folder_path_req = f'{folder_path}/portfolio_lead_lag/{sim_type}/{lead}/LS'
            print(folder_path_req)
            os.makedirs(folder_path_req, exist_ok = True)

# %%
create_directories()
# Out:
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q2
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q3
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q4
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS

# %%
folder_path = '/data/workspace_files/parquet_files'
for score_type in ['cosine_similarity', 'jaccard_similarity']:
    for lead in range(1,13):  
        for year in range(1996, 2018):
            print(f"Running score_type {score_type}, lead :{lead}, year : {year}")
            for month in tqdm(range(1, 13)):
                if year == 1996 and month <= 1:
                    continue
                month_yr = f"{month_dict[month]}{year}"
                date_obj = datetime.strptime(month_yr, '%b%Y')
                check_write_file = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/Q{5}/{month_yr}.parquet'
                if os.path.exists(check_write_file):
                    print(f"{check_write_file} exists ")
                    continue
                cik_tick_map_req = get_n_mnths_return(date_obj, lead)
                score_path = f'{folder_path}/similarity_scores/{month_yr}.parquet'
                scores = pq.read_table(score_path).to_pandas()
                cik_tick_map_req['ret_clipped'] = cik_tick_map_req['ret'].clip(lower=-50.0, upper=50.0)
                scores = pd.merge(scores, cik_tick_map_req, how='inner', on=['cik'])
                for num_buckets in [5]:
                    # Create quantile buckets
                    buckets = pd.qcut(scores[score_type], q=num_buckets, labels=False)
                    if month == 1:
                        prev_month = 12
                        prev_yr = year-1
                    else:
                        prev_month = month-1
                        prev_yr = year
                    prev_month_yr = f"{month_dict[prev_month]}{prev_yr}"
                    for i in range(num_buckets):
                        for history in [6]:
                            print(f'Running for lookback window = {history} and leading period = {lead}')
                            # Filter scores for the current quantile
                            quantile_positions = scores[buckets == i].copy(deep = True)
                            quantile_positions['pos_type'] = 'Quantile_' + str(i+1)
                            quantile_positions['num_months'] = 1

                            port_path = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/Q{i+1}/{prev_month_yr}.parquet'
                            if os.path.exists(port_path):
                                prev_positions = pq.read_table(port_path).to_pandas().copy(deep = True)
                                prev_positions['num_months'] = prev_positions['num_months'] + 1
                                prev_positions = prev_positions[prev_positions['num_months'] <= history]
                                print(f'Prev Holdings {len(prev_positions)}')
                                quantile_positions = pd.concat([quantile_positions, prev_positions], axis = 0).reset_index(drop=True)

                            print(f'Before dropping dupes: {len(quantile_positions)}')
                            idxes = quantile_positions.groupby('cik')['num_months'].idxmin()
                            quantile_positions = quantile_positions.loc[idxes]

                            quantile_positions['weight'] = 1/len(quantile_positions)
                            quantile_positions['date'] = month_yr

                            print(f'After dropping dupes: {len(quantile_positions)}')
                            quantile_positions = quantile_positions[['date', 'cik', 'pos_type', 'num_months', 'weight', 'ret', 'ret_clipped', 'filing_date', 'cshtrm']]

                            # Save to Parquet
                            quantile_file_path = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/Q{i+1}/{month_yr}.parquet'
                            quantile_positions.to_parquet(quantile_file_path)

                            print(f'Quantile {i+1} Holdings: {len(quantile_positions)}')
# Out:
# Total rows after selecting rows with max cshtrm: 11774
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1110
# Before dropping dupes: 1868
# After dropping dupes: 1576
# Quantile 1 Holdings: 1576
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1162
# Before dropping dupes: 1919
# After dropping dupes: 1718
# Quantile 2 Holdings: 1718
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1169
# Before dropping dupes: 1926
# After dropping dupes: 1731
# Quantile 3 Holdings: 1731
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1173
# Before dropping dupes: 1930
# After dropping dupes: 1731
# Quantile 4 Holdings: 1731
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1131
# Before dropping dupes: 1889
# After dropping dupes: 1508
# Quantile 5 Holdings: 1508
# 2014-02-01
# 2014-03-01
# Total rows: 13095
# Unique cusip count: 11864
# Total rows after selecting rows with max cshtrm: 11653
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1525
# Before dropping dupes: 1604
# After dropping dupes: 1562
# Quantile 1 Holdings: 1562
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1638
# Before dropping dupes: 1716
# After dropping dupes: 1691
# Quantile 2 Holdings: 1691
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1652
# Before dropping dupes: 1730
# After dropping dupes: 1715
# Quantile 3 Holdings: 1715
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1656
# Before dropping dupes: 1734
# After dropping dupes: 1715
# Quantile 4 Holdings: 1715
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1452
# Before dropping dupes: 1530
# After dropping dupes: 1504
# Quantile 5 Holdings: 1504
# 2014-03-01
# 2014-04-01
# Total rows: 13071
# Unique cusip count: 11862
# Total rows after selecting rows with max cshtrm: 11647
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1525
# Before dropping dupes: 1701
# After dropping dupes: 1618
# Quantile 1 Holdings: 1618
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1639
# Before dropping dupes: 1814
# After dropping dupes: 1734
# Quantile 2 Holdings: 1734
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1669
# Before dropping dupes: 1844
# After dropping dupes: 1768
# Quantile 3 Holdings: 1768
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1657
# Before dropping dupes: 1832
# After dropping dupes: 1747
# Quantile 4 Holdings: 1747
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1465
# Before dropping dupes: 1641
# After dropping dupes: 1551
# Quantile 5 Holdings: 1551
# 2014-04-01
# 2014-05-01
# Total rows: 13103
# Unique cusip count: 11884
# Total rows after selecting rows with max cshtrm: 11669
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1371
# Before dropping dupes: 2088
# After dropping dupes: 1700
# Quantile 1 Holdings: 1700
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1469
# Before dropping dupes: 2186
# After dropping dupes: 1847
# Quantile 2 Holdings: 1847
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1482
# Before dropping dupes: 2199
# After dropping dupes: 1864
# Quantile 3 Holdings: 1864
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1464
# Before dropping dupes: 2181
# After dropping dupes: 1823
# Quantile 4 Holdings: 1823
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1301
# Before dropping dupes: 2018
# After dropping dupes: 1504
# Quantile 5 Holdings: 1504
# 2014-05-01
# 2014-06-01
# Total rows: 13112
# Unique cusip count: 11911
# Total rows after selecting rows with max cshtrm: 11698
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1495
# Before dropping dupes: 1588
# After dropping dupes: 1548
# Quantile 1 Holdings: 1548
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1604
# Before dropping dupes: 1696
# After dropping dupes: 1670
# Quantile 2 Holdings: 1670
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1601
# Before dropping dupes: 1694
# After dropping dupes: 1667
# Quantile 3 Holdings: 1667
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1579
# Before dropping dupes: 1671
# After dropping dupes: 1648
# Quantile 4 Holdings: 1648
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1348
# Before dropping dupes: 1441
# After dropping dupes: 1391
# Quantile 5 Holdings: 1391
# 2014-06-01
# 2014-07-01
# Total rows: 13071
# Unique cusip count: 11886
# Total rows after selecting rows with max cshtrm: 11676
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1426
# Before dropping dupes: 1624
# After dropping dupes: 1533
# Quantile 1 Holdings: 1533
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1491
# Before dropping dupes: 1689
# After dropping dupes: 1619
# Quantile 2 Holdings: 1619
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1502
# Before dropping dupes: 1699
# After dropping dupes: 1618
# Quantile 3 Holdings: 1618
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1474
# Before dropping dupes: 1672
# After dropping dupes: 1578
# Quantile 4 Holdings: 1578
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1276
# Before dropping dupes: 1474
# After dropping dupes: 1358
# Quantile 5 Holdings: 1358
# 2014-07-01
# 2014-08-01
# Total rows: 13057
# Unique cusip count: 11865
# Total rows after selecting rows with max cshtrm: 11653
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1126
# Before dropping dupes: 1849
# After dropping dupes: 1503
# Quantile 1 Holdings: 1503
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1165
# Before dropping dupes: 1888
# After dropping dupes: 1595
# Quantile 2 Holdings: 1595
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1159
# Before dropping dupes: 1884
# After dropping dupes: 1592
# Quantile 3 Holdings: 1592
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1153
# Before dropping dupes: 1874
# After dropping dupes: 1560
# Quantile 4 Holdings: 1560
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1096
# Before dropping dupes: 1819
# After dropping dupes: 1343
# Quantile 5 Holdings: 1343
# 2014-08-01
# 2014-09-01
# Total rows: 13070
# Unique cusip count: 11883
# Total rows after selecting rows with max cshtrm: 11678
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1457
# Before dropping dupes: 1539
# After dropping dupes: 1506
# Quantile 1 Holdings: 1506
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1547
# Before dropping dupes: 1629
# After dropping dupes: 1597
# Quantile 2 Holdings: 1597
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1539
# Before dropping dupes: 1620
# After dropping dupes: 1598
# Quantile 3 Holdings: 1598
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1508
# Before dropping dupes: 1590
# After dropping dupes: 1565
# Quantile 4 Holdings: 1565
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1308
# Before dropping dupes: 1390
# After dropping dupes: 1355
# Quantile 5 Holdings: 1355
# Running score_type jaccard_similarity, lead :8, year : 2014
# 2014-09-01
# 2014-10-01
# Total rows: 13079
# Unique cusip count: 11895
# Total rows after selecting rows with max cshtrm: 11684
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1395
# Before dropping dupes: 1476
# After dropping dupes: 1430
# Quantile 1 Holdings: 1430
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1476
# Before dropping dupes: 1556
# After dropping dupes: 1535
# Quantile 2 Holdings: 1535
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1491
# Before dropping dupes: 1571
# After dropping dupes: 1551
# Quantile 3 Holdings: 1551
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1471
# Before dropping dupes: 1551
# After dropping dupes: 1524
# Quantile 4 Holdings: 1524
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1269
# Before dropping dupes: 1349
# After dropping dupes: 1300
# Quantile 5 Holdings: 1300
# 2014-10-01
# 2014-11-01
# Total rows: 13094
# Unique cusip count: 11895
# Total rows after selecting rows with max cshtrm: 11681
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1078
# Before dropping dupes: 1491
# After dropping dupes: 1341
# Quantile 1 Holdings: 1341
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1107
# Before dropping dupes: 1519
# After dropping dupes: 1416
# Quantile 2 Holdings: 1416
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1133
# Before dropping dupes: 1545
# After dropping dupes: 1439
# Quantile 3 Holdings: 1439
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1122
# Before dropping dupes: 1534
# After dropping dupes: 1424
# Quantile 4 Holdings: 1424
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1035
# Before dropping dupes: 1448
# After dropping dupes: 1308
# Quantile 5 Holdings: 1308
# 2014-11-01
# 2014-12-01
# Total rows: 13106
# Unique cusip count: 11909
# Total rows after selecting rows with max cshtrm: 11696
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1299
# Before dropping dupes: 1736
# After dropping dupes: 1557
# Quantile 1 Holdings: 1557
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1356
# Before dropping dupes: 1792
# After dropping dupes: 1681
# Quantile 2 Holdings: 1681
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1365
# Before dropping dupes: 1801
# After dropping dupes: 1704
# Quantile 3 Holdings: 1704
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1366
# Before dropping dupes: 1802
# After dropping dupes: 1675
# Quantile 4 Holdings: 1675
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1273
# Before dropping dupes: 1709
# After dropping dupes: 1486
# Quantile 5 Holdings: 1486
# 2014-12-01
# 2015-01-01
# Total rows: 13152
# Unique cusip count: 11946
# Total rows after selecting rows with max cshtrm: 11737
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1431
# Before dropping dupes: 1660
# After dropping dupes: 1562
# Quantile 1 Holdings: 1562
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1543
# Before dropping dupes: 1771
# After dropping dupes: 1708
# Quantile 2 Holdings: 1708
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1564
# Before dropping dupes: 1792
# After dropping dupes: 1728
# Quantile 3 Holdings: 1728
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1525
# Before dropping dupes: 1753
# After dropping dupes: 1692
# Quantile 4 Holdings: 1692
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1385
# Before dropping dupes: 1613
# After dropping dupes: 1514
# Quantile 5 Holdings: 1514
# 2015-01-01
# 2015-02-01
# Total rows: 13112
# Unique cusip count: 11907
# Total rows after selecting rows with max cshtrm: 11696
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1111
# Before dropping dupes: 1864
# After dropping dupes: 1578
# Quantile 1 Holdings: 1578
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1176
# Before dropping dupes: 1928
# After dropping dupes: 1705
# Quantile 2 Holdings: 1705
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1168
# Before dropping dupes: 1921
# After dropping dupes: 1722
# Quantile 3 Holdings: 1722
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1179
# Before dropping dupes: 1931
# After dropping dupes: 1726
# Quantile 4 Holdings: 1726
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1123
# Before dropping dupes: 1876
# After dropping dupes: 1479
# Quantile 5 Holdings: 1479
# 2015-02-01
# 2015-03-01
# Total rows: 13084
# Unique cusip count: 11912
# Total rows after selecting rows with max cshtrm: 11694
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1535
# Before dropping dupes: 1624
# After dropping dupes: 1586
# Quantile 1 Holdings: 1586
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1647
# Before dropping dupes: 1736
# After dropping dupes: 1709
# Quantile 2 Holdings: 1709
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1664
# Before dropping dupes: 1752
# After dropping dupes: 1732
# Quantile 3 Holdings: 1732
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1665
# Before dropping dupes: 1754
# After dropping dupes: 1739
# Quantile 4 Holdings: 1739
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1432
# Before dropping dupes: 1521
# After dropping dupes: 1479
# Quantile 5 Holdings: 1479
# 2015-03-01
# 2015-04-01
# Total rows: 12957
# Unique cusip count: 11786
# Total rows after selecting rows with max cshtrm: 11580
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1556
# Before dropping dupes: 1748
# After dropping dupes: 1661
# Quantile 1 Holdings: 1661
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1659
# Before dropping dupes: 1850
# After dropping dupes: 1768
# Quantile 2 Holdings: 1768
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1682
# Before dropping dupes: 1873
# After dropping dupes: 1801
# Quantile 3 Holdings: 1801
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1684
# Before dropping dupes: 1875
# After dropping dupes: 1783
# Quantile 4 Holdings: 1783
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1446
# Before dropping dupes: 1637
# After dropping dupes: 1534
# Quantile 5 Holdings: 1534
# 2015-04-01
# 2015-05-01
# Total rows: 12936
# Unique cusip count: 11780
# Total rows after selecting rows with max cshtrm: 11570
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1411
# Before dropping dupes: 2120
# After dropping dupes: 1730
# Quantile 1 Holdings: 1730
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1477
# Before dropping dupes: 2185
# After dropping dupes: 1852
# Quantile 2 Holdings: 1852
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1518
# Before dropping dupes: 2226
# After dropping dupes: 1916
# Quantile 3 Holdings: 1916
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1493
# Before dropping dupes: 2201
# After dropping dupes: 1848
# Quantile 4 Holdings: 1848
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1295
# Before dropping dupes: 2003
# After dropping dupes: 1531
# Quantile 5 Holdings: 1531
# 2015-05-01
# 2015-06-01
# Total rows: 12906
# Unique cusip count: 11751
# Total rows after selecting rows with max cshtrm: 11536
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1503
# Before dropping dupes: 1601
# After dropping dupes: 1561
# Quantile 1 Holdings: 1561
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1586
# Before dropping dupes: 1683
# After dropping dupes: 1641
# Quantile 2 Holdings: 1641
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1629
# Before dropping dupes: 1727
# After dropping dupes: 1700
# Quantile 3 Holdings: 1700
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1573
# Before dropping dupes: 1670
# After dropping dupes: 1644
# Quantile 4 Holdings: 1644
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1362
# Before dropping dupes: 1460
# After dropping dupes: 1407
# Quantile 5 Holdings: 1407
# 2015-06-01
# 2015-07-01
# Total rows: 12935
# Unique cusip count: 11766
# Total rows after selecting rows with max cshtrm: 11556
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1435
# Before dropping dupes: 1658
# After dropping dupes: 1560
# Quantile 1 Holdings: 1560
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1500
# Before dropping dupes: 1722
# After dropping dupes: 1642
# Quantile 2 Holdings: 1642
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1531
# Before dropping dupes: 1753
# After dropping dupes: 1650
# Quantile 3 Holdings: 1650
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1500
# Before dropping dupes: 1722
# After dropping dupes: 1622
# Quantile 4 Holdings: 1622
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1315
# Before dropping dupes: 1538
# After dropping dupes: 1418
# Quantile 5 Holdings: 1418
# 2015-07-01
# 2015-08-01
# Total rows: 12925
# Unique cusip count: 11762
# Total rows after selecting rows with max cshtrm: 11547
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1174
# Before dropping dupes: 1866
# After dropping dupes: 1547
# Quantile 1 Holdings: 1547
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1187
# Before dropping dupes: 1878
# After dropping dupes: 1611
# Quantile 2 Holdings: 1611
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1200
# Before dropping dupes: 1892
# After dropping dupes: 1625
# Quantile 3 Holdings: 1625
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1187
# Before dropping dupes: 1878
# After dropping dupes: 1577
# Quantile 4 Holdings: 1577
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1142
# Before dropping dupes: 1834
# After dropping dupes: 1388
# Quantile 5 Holdings: 1388
# 2015-08-01
# 2015-09-01
# Total rows: 12905
# Unique cusip count: 11739
# Total rows after selecting rows with max cshtrm: 11527
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1492
# Before dropping dupes: 1582
# After dropping dupes: 1541
# Quantile 1 Holdings: 1541
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1560
# Before dropping dupes: 1649
# After dropping dupes: 1616
# Quantile 2 Holdings: 1616
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1561
# Before dropping dupes: 1650
# After dropping dupes: 1613
# Quantile 3 Holdings: 1613
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1516
# Before dropping dupes: 1605
# After dropping dupes: 1569
# Quantile 4 Holdings: 1569
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1338
# Before dropping dupes: 1428
# After dropping dupes: 1385
# Quantile 5 Holdings: 1385
# Running score_type jaccard_similarity, lead :8, year : 2015
# 2015-09-01
# 2015-10-01
# Total rows: 12851
# Unique cusip count: 11709
# Total rows after selecting rows with max cshtrm: 11494
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1430
# Before dropping dupes: 1502
# After dropping dupes: 1477
# Quantile 1 Holdings: 1477
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1485
# Before dropping dupes: 1556
# After dropping dupes: 1528
# Quantile 2 Holdings: 1528
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1497
# Before dropping dupes: 1568
# After dropping dupes: 1557
# Quantile 3 Holdings: 1557
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1453
# Before dropping dupes: 1524
# After dropping dupes: 1509
# Quantile 4 Holdings: 1509
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1302
# Before dropping dupes: 1373
# After dropping dupes: 1331
# Quantile 5 Holdings: 1331
# 2015-10-01
# 2015-11-01
# Total rows: 12838
# Unique cusip count: 11694
# Total rows after selecting rows with max cshtrm: 11473
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1094
# Before dropping dupes: 1506
# After dropping dupes: 1392
# Quantile 1 Holdings: 1392
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1105
# Before dropping dupes: 1516
# After dropping dupes: 1418
# Quantile 2 Holdings: 1418
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1124
# Before dropping dupes: 1536
# After dropping dupes: 1440
# Quantile 3 Holdings: 1440
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1119
# Before dropping dupes: 1530
# After dropping dupes: 1428
# Quantile 4 Holdings: 1428
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1048
# Before dropping dupes: 1460
# After dropping dupes: 1307
# Quantile 5 Holdings: 1307
# 2015-11-01
# 2015-12-01
# Total rows: 12820
# Unique cusip count: 11670
# Total rows after selecting rows with max cshtrm: 11456
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1338
# Before dropping dupes: 1769
# After dropping dupes: 1605
# Quantile 1 Holdings: 1605
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1356
# Before dropping dupes: 1787
# After dropping dupes: 1682
# Quantile 2 Holdings: 1682
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1379
# Before dropping dupes: 1810
# After dropping dupes: 1735
# Quantile 3 Holdings: 1735
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1372
# Before dropping dupes: 1803
# After dropping dupes: 1667
# Quantile 4 Holdings: 1667
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1265
# Before dropping dupes: 1696
# After dropping dupes: 1475
# Quantile 5 Holdings: 1475
# 2015-12-01
# 2016-01-01
# Total rows: 12872
# Unique cusip count: 11729
# Total rows after selecting rows with max cshtrm: 11521
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1442
# Before dropping dupes: 1651
# After dropping dupes: 1570
# Quantile 1 Holdings: 1570
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1515
# Before dropping dupes: 1723
# After dropping dupes: 1657
# Quantile 2 Holdings: 1657
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1561
# Before dropping dupes: 1769
# After dropping dupes: 1703
# Quantile 3 Holdings: 1703
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1497
# Before dropping dupes: 1705
# After dropping dupes: 1655
# Quantile 4 Holdings: 1655
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1337
# Before dropping dupes: 1546
# After dropping dupes: 1464
# Quantile 5 Holdings: 1464
# 2016-01-01
# 2016-02-01
# Total rows: 12814
# Unique cusip count: 11688
# Total rows after selecting rows with max cshtrm: 11460
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1113
# Before dropping dupes: 1840
# After dropping dupes: 1565
# Quantile 1 Holdings: 1565
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1131
# Before dropping dupes: 1858
# After dropping dupes: 1670
# Quantile 2 Holdings: 1670
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1135
# Before dropping dupes: 1861
# After dropping dupes: 1693
# Quantile 3 Holdings: 1693
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1151
# Before dropping dupes: 1878
# After dropping dupes: 1673
# Quantile 4 Holdings: 1673
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1102
# Before dropping dupes: 1829
# After dropping dupes: 1460
# Quantile 5 Holdings: 1460
# 2016-02-01
# 2016-03-01
# Total rows: 12746
# Unique cusip count: 11643
# Total rows after selecting rows with max cshtrm: 11429
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1514
# Before dropping dupes: 1602
# After dropping dupes: 1571
# Quantile 1 Holdings: 1571
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1614
# Before dropping dupes: 1701
# After dropping dupes: 1676
# Quantile 2 Holdings: 1676
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1630
# Before dropping dupes: 1717
# After dropping dupes: 1695
# Quantile 3 Holdings: 1695
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1603
# Before dropping dupes: 1690
# After dropping dupes: 1674
# Quantile 4 Holdings: 1674
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1406
# Before dropping dupes: 1493
# After dropping dupes: 1468
# Quantile 5 Holdings: 1468
# 2016-03-01
# 2016-04-01
# Total rows: 12735
# Unique cusip count: 11633
# Total rows after selecting rows with max cshtrm: 11423
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1523
# Before dropping dupes: 1731
# After dropping dupes: 1647
# Quantile 1 Holdings: 1647
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1627
# Before dropping dupes: 1834
# After dropping dupes: 1732
# Quantile 2 Holdings: 1732
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1648
# Before dropping dupes: 1855
# After dropping dupes: 1759
# Quantile 3 Holdings: 1759
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1618
# Before dropping dupes: 1825
# After dropping dupes: 1726
# Quantile 4 Holdings: 1726
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1436
# Before dropping dupes: 1644
# After dropping dupes: 1527
# Quantile 5 Holdings: 1527
# 2016-04-01
# 2016-05-01
# Total rows: 12729
# Unique cusip count: 11592
# Total rows after selecting rows with max cshtrm: 11385
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1386
# Before dropping dupes: 2074
# After dropping dupes: 1692
# Quantile 1 Holdings: 1692
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1438
# Before dropping dupes: 2125
# After dropping dupes: 1809
# Quantile 2 Holdings: 1809
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1468
# Before dropping dupes: 2155
# After dropping dupes: 1849
# Quantile 3 Holdings: 1849
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1428
# Before dropping dupes: 2115
# After dropping dupes: 1757
# Quantile 4 Holdings: 1757
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1283
# Before dropping dupes: 1971
# After dropping dupes: 1497
# Quantile 5 Holdings: 1497
# 2016-05-01
# 2016-06-01
# Total rows: 12698
# Unique cusip count: 11549
# Total rows after selecting rows with max cshtrm: 11340
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1473
# Before dropping dupes: 1562
# After dropping dupes: 1527
# Quantile 1 Holdings: 1527
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1556
# Before dropping dupes: 1644
# After dropping dupes: 1613
# Quantile 2 Holdings: 1613
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1572
# Before dropping dupes: 1661
# After dropping dupes: 1637
# Quantile 3 Holdings: 1637
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1505
# Before dropping dupes: 1593
# After dropping dupes: 1565
# Quantile 4 Holdings: 1565
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1341
# Before dropping dupes: 1430
# After dropping dupes: 1383
# Quantile 5 Holdings: 1383
# 2016-06-01
# 2016-07-01
# Total rows: 12675
# Unique cusip count: 11523
# Total rows after selecting rows with max cshtrm: 11313
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1419
# Before dropping dupes: 1610
# After dropping dupes: 1525
# Quantile 1 Holdings: 1525
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1483
# Before dropping dupes: 1674
# After dropping dupes: 1590
# Quantile 2 Holdings: 1590
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1497
# Before dropping dupes: 1687
# After dropping dupes: 1598
# Quantile 3 Holdings: 1598
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1434
# Before dropping dupes: 1625
# After dropping dupes: 1541
# Quantile 4 Holdings: 1541
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1278
# Before dropping dupes: 1469
# After dropping dupes: 1357
# Quantile 5 Holdings: 1357
# 2016-07-01
# 2016-08-01
# Total rows: 12657
# Unique cusip count: 11496
# Total rows after selecting rows with max cshtrm: 11287
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1147
# Before dropping dupes: 1841
# After dropping dupes: 1497
# Quantile 1 Holdings: 1497
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1157
# Before dropping dupes: 1850
# After dropping dupes: 1584
# Quantile 2 Holdings: 1584
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1155
# Before dropping dupes: 1848
# After dropping dupes: 1573
# Quantile 3 Holdings: 1573
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1151
# Before dropping dupes: 1844
# After dropping dupes: 1527
# Quantile 4 Holdings: 1527
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1089
# Before dropping dupes: 1782
# After dropping dupes: 1341
# Quantile 5 Holdings: 1341
# 2016-08-01
# 2016-09-01
# Total rows: 12658
# Unique cusip count: 11478
# Total rows after selecting rows with max cshtrm: 11266
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1450
# Before dropping dupes: 1523
# After dropping dupes: 1492
# Quantile 1 Holdings: 1492
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1529
# Before dropping dupes: 1601
# After dropping dupes: 1581
# Quantile 2 Holdings: 1581
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1513
# Before dropping dupes: 1586
# After dropping dupes: 1564
# Quantile 3 Holdings: 1564
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1467
# Before dropping dupes: 1539
# After dropping dupes: 1517
# Quantile 4 Holdings: 1517
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1299
# Before dropping dupes: 1372
# After dropping dupes: 1337
# Quantile 5 Holdings: 1337
# Running score_type jaccard_similarity, lead :8, year : 2016
# 2016-09-01
# 2016-10-01
# Total rows: 12588
# Unique cusip count: 11420
# Total rows after selecting rows with max cshtrm: 11208
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1354
# Before dropping dupes: 1419
# After dropping dupes: 1393
# Quantile 1 Holdings: 1393
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1443
# Before dropping dupes: 1508
# After dropping dupes: 1489
# Quantile 2 Holdings: 1489
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1435
# Before dropping dupes: 1500
# After dropping dupes: 1485
# Quantile 3 Holdings: 1485
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1394
# Before dropping dupes: 1459
# After dropping dupes: 1440
# Quantile 4 Holdings: 1440
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1256
# Before dropping dupes: 1321
# After dropping dupes: 1277
# Quantile 5 Holdings: 1277
# 2016-10-01
# 2016-11-01
# Total rows: 12541
# Unique cusip count: 11386
# Total rows after selecting rows with max cshtrm: 11174
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1043
# Before dropping dupes: 1495
# After dropping dupes: 1368
# Quantile 1 Holdings: 1368
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1065
# Before dropping dupes: 1517
# After dropping dupes: 1413
# Quantile 2 Holdings: 1413
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1070
# Before dropping dupes: 1521
# After dropping dupes: 1421
# Quantile 3 Holdings: 1421
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1067
# Before dropping dupes: 1519
# After dropping dupes: 1414
# Quantile 4 Holdings: 1414
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 997
# Before dropping dupes: 1449
# After dropping dupes: 1276
# Quantile 5 Holdings: 1276
# 2016-11-01
# 2016-12-01
# Total rows: 12554
# Unique cusip count: 11401
# Total rows after selecting rows with max cshtrm: 11191
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1318
# Before dropping dupes: 1701
# After dropping dupes: 1554
# Quantile 1 Holdings: 1554
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1348
# Before dropping dupes: 1731
# After dropping dupes: 1633
# Quantile 2 Holdings: 1633
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1357
# Before dropping dupes: 1739
# After dropping dupes: 1667
# Quantile 3 Holdings: 1667
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1353
# Before dropping dupes: 1736
# After dropping dupes: 1647
# Quantile 4 Holdings: 1647
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1237
# Before dropping dupes: 1620
# After dropping dupes: 1445
# Quantile 5 Holdings: 1445
# 2016-12-01
# 2017-01-01
# Total rows: 12620
# Unique cusip count: 11442
# Total rows after selecting rows with max cshtrm: 11232
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1412
# Before dropping dupes: 1619
# After dropping dupes: 1546
# Quantile 1 Holdings: 1546
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1501
# Before dropping dupes: 1707
# After dropping dupes: 1634
# Quantile 2 Holdings: 1634
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1517
# Before dropping dupes: 1724
# After dropping dupes: 1664
# Quantile 3 Holdings: 1664
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1512
# Before dropping dupes: 1718
# After dropping dupes: 1665
# Quantile 4 Holdings: 1665
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1340
# Before dropping dupes: 1547
# After dropping dupes: 1456
# Quantile 5 Holdings: 1456
# 2017-01-01
# 2017-02-01
# Total rows: 12572
# Unique cusip count: 11393
# Total rows after selecting rows with max cshtrm: 11186
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1076
# Before dropping dupes: 1779
# After dropping dupes: 1519
# Quantile 1 Holdings: 1519
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1097
# Before dropping dupes: 1800
# After dropping dupes: 1626
# Quantile 2 Holdings: 1626
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1113
# Before dropping dupes: 1816
# After dropping dupes: 1657
# Quantile 3 Holdings: 1657
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1122
# Before dropping dupes: 1825
# After dropping dupes: 1623
# Quantile 4 Holdings: 1623
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1076
# Before dropping dupes: 1779
# After dropping dupes: 1440
# Quantile 5 Holdings: 1440
# 2017-02-01
# 2017-03-01
# Total rows: 12585
# Unique cusip count: 11403
# Total rows after selecting rows with max cshtrm: 11198
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1484
# Before dropping dupes: 1556
# After dropping dupes: 1524
# Quantile 1 Holdings: 1524
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1583
# Before dropping dupes: 1655
# After dropping dupes: 1626
# Quantile 2 Holdings: 1626
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1599
# Before dropping dupes: 1671
# After dropping dupes: 1655
# Quantile 3 Holdings: 1655
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1568
# Before dropping dupes: 1640
# After dropping dupes: 1622
# Quantile 4 Holdings: 1622
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1398
# Before dropping dupes: 1470
# After dropping dupes: 1433
# Quantile 5 Holdings: 1433
# 2017-03-01
# 2017-04-01
# Total rows: 12587
# Unique cusip count: 11395
# Total rows after selecting rows with max cshtrm: 11192
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1491
# Before dropping dupes: 1656
# After dropping dupes: 1575
# Quantile 1 Holdings: 1575
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1581
# Before dropping dupes: 1745
# After dropping dupes: 1677
# Quantile 2 Holdings: 1677
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1611
# Before dropping dupes: 1775
# After dropping dupes: 1697
# Quantile 3 Holdings: 1697
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1574
# Before dropping dupes: 1738
# After dropping dupes: 1655
# Quantile 4 Holdings: 1655
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1404
# Before dropping dupes: 1568
# After dropping dupes: 1466
# Quantile 5 Holdings: 1466
# 2017-04-01
# 2017-05-01
# Total rows: 12549
# Unique cusip count: 11370
# Total rows after selecting rows with max cshtrm: 11158
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1292
# Before dropping dupes: 1979
# After dropping dupes: 1624
# Quantile 1 Holdings: 1624
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1371
# Before dropping dupes: 2057
# After dropping dupes: 1745
# Quantile 2 Holdings: 1745
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1360
# Before dropping dupes: 2046
# After dropping dupes: 1755
# Quantile 3 Holdings: 1755
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1340
# Before dropping dupes: 2026
# After dropping dupes: 1691
# Quantile 4 Holdings: 1691
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1180
# Before dropping dupes: 1866
# After dropping dupes: 1404
# Quantile 5 Holdings: 1404
# 2017-05-01
# 2017-06-01
# Total rows: 12585
# Unique cusip count: 11399
# Total rows after selecting rows with max cshtrm: 11188
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1407
# Before dropping dupes: 1483
# After dropping dupes: 1458
# Quantile 1 Holdings: 1458
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1501
# Before dropping dupes: 1576
# After dropping dupes: 1556
# Quantile 2 Holdings: 1556
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1501
# Before dropping dupes: 1576
# After dropping dupes: 1555
# Quantile 3 Holdings: 1555
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1455
# Before dropping dupes: 1530
# After dropping dupes: 1501
# Quantile 4 Holdings: 1501
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1249
# Before dropping dupes: 1325
# After dropping dupes: 1288
# Quantile 5 Holdings: 1288
# 2017-06-01
# 2017-07-01
# Total rows: 12550
# Unique cusip count: 11363
# Total rows after selecting rows with max cshtrm: 11150
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1343
# Before dropping dupes: 1514
# After dropping dupes: 1439
# Quantile 1 Holdings: 1439
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1404
# Before dropping dupes: 1574
# After dropping dupes: 1519
# Quantile 2 Holdings: 1519
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1413
# Before dropping dupes: 1583
# After dropping dupes: 1514
# Quantile 3 Holdings: 1514
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1369
# Before dropping dupes: 1539
# After dropping dupes: 1455
# Quantile 4 Holdings: 1455
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1187
# Before dropping dupes: 1358
# After dropping dupes: 1256
# Quantile 5 Holdings: 1256
# 2017-07-01
# 2017-08-01
# Total rows: 12518
# Unique cusip count: 11341
# Total rows after selecting rows with max cshtrm: 11131
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1066
# Before dropping dupes: 1747
# After dropping dupes: 1435
# Quantile 1 Holdings: 1435
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1086
# Before dropping dupes: 1766
# After dropping dupes: 1493
# Quantile 2 Holdings: 1493
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1074
# Before dropping dupes: 1755
# After dropping dupes: 1483
# Quantile 3 Holdings: 1483
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1054
# Before dropping dupes: 1734
# After dropping dupes: 1427
# Quantile 4 Holdings: 1427
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 993
# Before dropping dupes: 1674
# After dropping dupes: 1248
# Quantile 5 Holdings: 1248
# 2017-08-01
# 2017-09-01
# Total rows: 12469
# Unique cusip count: 11300
# Total rows after selecting rows with max cshtrm: 11095
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1395
# Before dropping dupes: 1479
# After dropping dupes: 1442
# Quantile 1 Holdings: 1442
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1448
# Before dropping dupes: 1532
# After dropping dupes: 1508
# Quantile 2 Holdings: 1508
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1445
# Before dropping dupes: 1528
# After dropping dupes: 1508
# Quantile 3 Holdings: 1508
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1388
# Before dropping dupes: 1472
# After dropping dupes: 1448
# Quantile 4 Holdings: 1448
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1223
# Before dropping dupes: 1307
# After dropping dupes: 1274
# Quantile 5 Holdings: 1274
# Running score_type jaccard_similarity, lead :8, year : 2017
# 2017-09-01
# 2017-10-01
# Total rows: 12453
# Unique cusip count: 11276
# Total rows after selecting rows with max cshtrm: 11063
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1335
# Before dropping dupes: 1390
# After dropping dupes: 1369
# Quantile 1 Holdings: 1369
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1396
# Before dropping dupes: 1451
# After dropping dupes: 1432
# Quantile 2 Holdings: 1432
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1399
# Before dropping dupes: 1453
# After dropping dupes: 1438
# Quantile 3 Holdings: 1438
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1359
# Before dropping dupes: 1414
# After dropping dupes: 1394
# Quantile 4 Holdings: 1394
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1208
# Before dropping dupes: 1263
# After dropping dupes: 1234
# Quantile 5 Holdings: 1234
# 2017-10-01
# 2017-11-01
# Total rows: 12466
# Unique cusip count: 11262
# Total rows after selecting rows with max cshtrm: 11049
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 994
# Before dropping dupes: 1394
# After dropping dupes: 1273
# Quantile 1 Holdings: 1273
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1018
# Before dropping dupes: 1417
# After dropping dupes: 1333
# Quantile 2 Holdings: 1333
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1022
# Before dropping dupes: 1421
# After dropping dupes: 1314
# Quantile 3 Holdings: 1314
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1016
# Before dropping dupes: 1415
# After dropping dupes: 1311
# Quantile 4 Holdings: 1311
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 970
# Before dropping dupes: 1369
# After dropping dupes: 1222
# Quantile 5 Holdings: 1222
# 2017-11-01
# 2017-12-01
# Total rows: 12510
# Unique cusip count: 11290
# Total rows after selecting rows with max cshtrm: 11075
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1227
# Before dropping dupes: 1636
# After dropping dupes: 1493
# Quantile 1 Holdings: 1493
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1289
# Before dropping dupes: 1697
# After dropping dupes: 1607
# Quantile 2 Holdings: 1607
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1265
# Before dropping dupes: 1673
# After dropping dupes: 1598
# Quantile 3 Holdings: 1598
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1266
# Before dropping dupes: 1674
# After dropping dupes: 1575
# Quantile 4 Holdings: 1575
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1190
# Before dropping dupes: 1598
# After dropping dupes: 1404
# Quantile 5 Holdings: 1404
# 2017-12-01
# 2018-01-01
# Total rows: 12592
# Unique cusip count: 11363
# Total rows after selecting rows with max cshtrm: 11153
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1370
# Before dropping dupes: 1547
# After dropping dupes: 1489
# Quantile 1 Holdings: 1489
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1476
# Before dropping dupes: 1652
# After dropping dupes: 1605
# Quantile 2 Holdings: 1605
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1472
# Before dropping dupes: 1648
# After dropping dupes: 1599
# Quantile 3 Holdings: 1599
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1446
# Before dropping dupes: 1622
# After dropping dupes: 1568
# Quantile 4 Holdings: 1568
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1315
# Before dropping dupes: 1491
# After dropping dupes: 1432
# Quantile 5 Holdings: 1432
# 2018-01-01
# 2018-02-01
# Total rows: 12609
# Unique cusip count: 11369
# Total rows after selecting rows with max cshtrm: 11161
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1019
# Before dropping dupes: 1727
# After dropping dupes: 1485
# Quantile 1 Holdings: 1485
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1064
# Before dropping dupes: 1771
# After dropping dupes: 1578
# Quantile 2 Holdings: 1578
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1064
# Before dropping dupes: 1771
# After dropping dupes: 1619
# Quantile 3 Holdings: 1619
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1057
# Before dropping dupes: 1764
# After dropping dupes: 1562
# Quantile 4 Holdings: 1562
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1040
# Before dropping dupes: 1747
# After dropping dupes: 1400
# Quantile 5 Holdings: 1400
# 2018-02-01
# 2018-03-01
# Total rows: 12574
# Unique cusip count: 11342
# Total rows after selecting rows with max cshtrm: 11130
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1448
# Before dropping dupes: 1524
# After dropping dupes: 1491
# Quantile 1 Holdings: 1491
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1519
# Before dropping dupes: 1595
# After dropping dupes: 1573
# Quantile 2 Holdings: 1573
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1548
# Before dropping dupes: 1623
# After dropping dupes: 1606
# Quantile 3 Holdings: 1606
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1499
# Before dropping dupes: 1575
# After dropping dupes: 1563
# Quantile 4 Holdings: 1563
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1355
# Before dropping dupes: 1431
# After dropping dupes: 1396
# Quantile 5 Holdings: 1396
# 2018-03-01
# 2018-04-01
# Total rows: 12566
# Unique cusip count: 11318
# Total rows after selecting rows with max cshtrm: 11103
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1459
# Before dropping dupes: 1603
# After dropping dupes: 1519
# Quantile 1 Holdings: 1519
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1541
# Before dropping dupes: 1684
# After dropping dupes: 1620
# Quantile 2 Holdings: 1620
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1571
# Before dropping dupes: 1715
# After dropping dupes: 1656
# Quantile 3 Holdings: 1656
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1529
# Before dropping dupes: 1672
# After dropping dupes: 1600
# Quantile 4 Holdings: 1600
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1368
# Before dropping dupes: 1512
# After dropping dupes: 1432
# Quantile 5 Holdings: 1432
# 2018-04-01
# 2018-05-01
# Total rows: 12496
# Unique cusip count: 11261
# Total rows after selecting rows with max cshtrm: 11048
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1262
# Before dropping dupes: 1951
# After dropping dupes: 1602
# Quantile 1 Holdings: 1602
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1331
# Before dropping dupes: 2019
# After dropping dupes: 1723
# Quantile 2 Holdings: 1723
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1362
# Before dropping dupes: 2051
# After dropping dupes: 1748
# Quantile 3 Holdings: 1748
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1311
# Before dropping dupes: 1999
# After dropping dupes: 1662
# Quantile 4 Holdings: 1662
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1189
# Before dropping dupes: 1878
# After dropping dupes: 1412
# Quantile 5 Holdings: 1412
# 2018-05-01
# 2018-06-01
# Total rows: 12472
# Unique cusip count: 11249
# Total rows after selecting rows with max cshtrm: 11031
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1382
# Before dropping dupes: 1461
# After dropping dupes: 1436
# Quantile 1 Holdings: 1436
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1475
# Before dropping dupes: 1553
# After dropping dupes: 1524
# Quantile 2 Holdings: 1524
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1465
# Before dropping dupes: 1544
# After dropping dupes: 1529
# Quantile 3 Holdings: 1529
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1409
# Before dropping dupes: 1487
# After dropping dupes: 1465
# Quantile 4 Holdings: 1465
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1246
# Before dropping dupes: 1325
# After dropping dupes: 1289
# Quantile 5 Holdings: 1289
# 2018-06-01
# 2018-07-01
# Total rows: 12449
# Unique cusip count: 11224
# Total rows after selecting rows with max cshtrm: 11008
# Running for lookback window = 6 and leading period = 8
# Prev Holdings 1336
# Before dropping dupes: 1511
# After dropping dupes: 1422
# Quantile 1 Holdings: 1422
# Running for lookback window = 6 and leading period = 8
# ...
# 100%|██████████| 12/12 [00:00<00:00, 1387.92it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1953.79it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1126.67it/s]
# 100%|██████████| 12/12 [00:00<00:00, 949.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2665.17it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7199.49it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2317.40it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2353.38it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2479.76it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5969.83it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5851.16it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1225.54it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5673.73it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5785.91it/s]
# 100%|██████████| 12/12 [00:00<00:00, 592.15it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5826.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 551.62it/s]
# 100%|██████████| 12/12 [00:00<00:00, 854.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2270.16it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2359.00it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2685.21it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1942.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 436.87it/s]
# 100%|██████████| 12/12 [00:02<00:00,  5.90it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3142.98it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4252.42it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1514.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1809.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3743.24it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3456.61it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2561.67it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2977.50it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2818.12it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2510.68it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6214.55it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7307.15it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7948.78it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6678.83it/s]
# 100%|██████████| 12/12 [00:00<00:00, 861.58it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7766.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2182.64it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10100.67it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8385.81it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8162.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10364.84it/s]
# 100%|██████████| 12/12 [00:00<00:00, 11338.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7043.33it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8406.82it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6135.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8549.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 11052.18it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8374.65it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7745.71it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10681.59it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10773.04it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7515.55it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1381.11it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5945.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7758.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3989.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 328.11it/s]
# 100%|██████████| 12/12 [00:00<00:00, 591.98it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1735.45it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1505.99it/s]
# 100%|██████████| 12/12 [00:00<00:00, 486.57it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1623.13it/s]
# 100%|██████████| 12/12 [00:00<00:00, 536.05it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3297.41it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8152.19it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1708.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7744.52it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6128.29it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7629.48it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8553.99it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7634.10it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3951.61it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7726.69it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8616.96it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5910.25it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7985.35it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2031.06it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7886.50it/s]
# 100%|██████████| 12/12 [00:00<00:00, 836.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1356.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10614.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8135.07it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1095.81it/s]
# 100%|██████████| 12/12 [00:00<00:00, 453.61it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2755.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 626.21it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8692.86it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10975.06it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6685.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4224.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7616.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2861.05it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7636.42it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3075.38it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10849.68it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8474.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 9247.04it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10463.96it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7457.65it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5346.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 660.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7770.83it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7875.39it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4793.95it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8028.66it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2045.09it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10324.44it/s]
# 100%|██████████| 12/12 [00:00<00:00, 9425.40it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7664.33it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5828.12it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1559.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3990.14it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8594.89it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2349.64it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7815.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7355.20it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3741.02it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7804.57it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2454.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7773.23it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6512.89it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5208.16it/s]
# 100%|██████████| 12/12 [00:00<00:00, 832.22it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7982.81it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8072.44it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1470.10it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3155.19it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7868.01it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6195.43it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7915.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8771.64it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2145.15it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7642.22it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6317.52it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4723.76it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8673.38it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7652.68it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3103.83it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7938.75it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5546.80it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1488.88it/s]
# 100%|██████████| 12/12 [00:00<00:00, 708.25it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7756.46it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5684.62it/s]
# 100%|██████████| 12/12 [00:00<00:00, 242.11it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1006.09it/s]
# 100%|██████████| 12/12 [00:00<00:00, 476.02it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7760.04it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1022.73it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1328.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 907.74it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5598.00it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3193.02it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2365.32it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5739.07it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2410.52it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5719.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2388.44it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5621.14it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1316.17it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7692.44it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4521.75it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6454.43it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5996.86it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6815.39it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5973.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 786.71it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6278.90it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6755.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6761.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 8420.89it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6477.69it/s]
# 100%|██████████| 12/12 [00:01<00:00,  7.35it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3041.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2728.59it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3075.00it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7338.04it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2299.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3845.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2216.08it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1983.59it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5216.26it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1855.27it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3307.59it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2777.22it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2098.46it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1141.80it/s]
# 100%|██████████| 12/12 [00:00<00:00, 10082.46it/s]
# 100%|██████████| 12/12 [00:00<00:00, 743.86it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3025.10it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2708.92it/s]
# 100%|██████████| 12/12 [00:00<00:00, 888.89it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5388.83it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6677.94it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2422.47it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2662.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3276.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 3480.27it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1136.92it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2925.07it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1977.82it/s]
# 100%|██████████| 12/12 [00:00<00:00, 13287.13it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4261.42it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2980.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7326.30it/s]
# 100%|██████████| 12/12 [00:00<00:00, 513.62it/s]
# 100%|██████████| 12/12 [00:00<00:00, 962.33it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4595.24it/s]
# 100%|██████████| 12/12 [00:00<00:00, 7384.34it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6874.97it/s]
# 100%|██████████| 12/12 [00:00<00:00, 923.70it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6738.74it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6754.11it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6626.07it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4473.53it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6970.18it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4206.57it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6800.66it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5071.71it/s]
# 100%|██████████| 12/12 [00:00<00:00, 4111.39it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6893.80it/s]
# 100%|██████████| 12/12 [00:00<00:00, 5215.17it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6300.91it/s]
# 100%|██████████| 12/12 [00:00<00:00, 2479.88it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6484.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 6685.04it/s]
# 100%|██████████| 12/12 [00:24<00:00,  2.01s/it]
# 100%|██████████| 12/12 [00:56<00:00,  4.67s/it]
# 100%|██████████| 12/12 [00:36<00:00,  3.05s/it]
# 100%|██████████| 12/12 [00:43<00:00,  3.63s/it]
# 100%|██████████| 12/12 [00:51<00:00,  4.31s/it]
# 100%|██████████| 12/12 [00:23<00:00,  1.99s/it]
# 100%|██████████| 12/12 [00:09<00:00,  1.25it/s]
# 100%|██████████| 12/12 [00:17<00:00,  1.44s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.79s/it]
# 100%|██████████| 12/12 [00:23<00:00,  1.94s/it]
# 100%|██████████| 12/12 [00:22<00:00,  1.88s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.15s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.00s/it]
# 100%|██████████| 12/12 [00:11<00:00,  1.01it/s]
# 100%|██████████| 12/12 [00:12<00:00,  1.01s/it]
# 100%|██████████| 12/12 [00:11<00:00,  1.01it/s]
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.19s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.22s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.20s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.17s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.18s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.17s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.16s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.14s/it]
# 100%|██████████| 12/12 [00:06<00:00,  1.92it/s]
# 100%|██████████| 12/12 [00:10<00:00,  1.14it/s]
# 100%|██████████| 12/12 [00:12<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.10s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.05s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.10s/it]
# 100%|██████████| 12/12 [00:19<00:00,  1.65s/it]
# 100%|██████████| 12/12 [00:25<00:00,  2.09s/it]
# 100%|██████████| 12/12 [00:23<00:00,  1.99s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.76s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.76s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.80s/it]
# 100%|██████████| 12/12 [00:23<00:00,  1.97s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.82s/it]
# 100%|██████████| 12/12 [00:25<00:00,  2.12s/it]
# 100%|██████████| 12/12 [00:23<00:00,  2.00s/it]
# 100%|██████████| 12/12 [00:24<00:00,  2.03s/it]
# 100%|██████████| 12/12 [00:24<00:00,  2.04s/it]
# 100%|██████████| 12/12 [00:24<00:00,  2.08s/it]
# 100%|██████████| 12/12 [00:22<00:00,  1.85s/it]
# 100%|██████████| 12/12 [00:20<00:00,  1.69s/it]
# 100%|██████████| 12/12 [00:06<00:00,  1.87it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.07it/s]
# 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# 100%|██████████| 12/12 [00:17<00:00,  1.42s/it]
# 100%|██████████| 12/12 [00:21<00:00,  1.79s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.06s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.04s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.02s/it]
# 100%|██████████| 12/12 [00:11<00:00,  1.01it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.02it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.02it/s]
# 100%|██████████| 12/12 [00:12<00:00,  1.07s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.20s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.23s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.19s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.17s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.16s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.14s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.13s/it]
# 100%|██████████| 12/12 [00:06<00:00,  1.95it/s]
# 100%|██████████| 12/12 [00:10<00:00,  1.12it/s]
# 100%|██████████| 12/12 [00:12<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.11s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.10s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.08s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# 100%|██████████| 12/12 [00:12<00:00,  1.00s/it]
# 100%|██████████| 12/12 [00:11<00:00,  1.02it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.01it/s]
# 100%|██████████| 12/12 [00:11<00:00,  1.03it/s]
# 100%|██████████| 12/12 [00:13<00:00,  1.09s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.20s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.20s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.21s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.18s/it]
# 100%|██████████| 12/12 [00:14<00:00,  1.18s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.15s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.14s/it]
# 100%|██████████| 12/12 [00:13<00:00,  1.12s/it]

# %%
def save_ls_portfolio(score_type, n_bucket):
    for year in range(1996,2018):
        for month in range(1, 13):
            for lead in range(1,13):
                if year == 1996 and month <= 1:
                        continue
                month_yr = f"{month_dict[month]}{year}"
                long_file_path = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/Q{n_bucket}/{month_yr}.parquet'
                print(long_file_path)
                short_file_path = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/Q1/{month_yr}.parquet'
                print(short_file_path)
                long_positions = pq.read_table(long_file_path).to_pandas()
                long_positions['pos_type'] = 1
                short_positions = pq.read_table(short_file_path).to_pandas()
                short_positions['pos_type'] = -1
                short_positions['weight'] = -1*short_positions['weight']
                positions = pd.concat([long_positions, short_positions])
                ls_file_path = f'{folder_path}/portfolio_lead_lag/{score_type}/{lead}/LS/{month_yr}.parquet'
                print(ls_file_path)
                positions.to_parquet(ls_file_path)

# %%
for score_type in ['cosine_similarity', 'jaccard_similarity']:
    for n_bucket in [5]:
        save_ls_portfolio(score_type, n_bucket)
# Out:
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Aug2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Sep2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Oct2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Nov2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Dec2015.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Jan2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Feb2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Mar2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Apr2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/May2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Jun2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Jul2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Aug2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/4/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/5/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/6/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/7/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/8/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/9/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/10/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/11/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q5/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/Q1/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/12/LS/Sep2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q5/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/Q1/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/1/LS/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q5/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/Q1/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/2/LS/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q5/Oct2016.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/cosine_similarity/3/Q1/Oct2016.parquet
# ...
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS/Aug2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS/Sep2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS/Oct2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS/Nov2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/1/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/2/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/3/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/4/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/5/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/6/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/7/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/8/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/9/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/10/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/11/LS/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q5/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/Q1/Dec2017.parquet
# /data/workspace_files/parquet_files/portfolio_lead_lag/jaccard_similarity/12/LS/Dec2017.parquet
